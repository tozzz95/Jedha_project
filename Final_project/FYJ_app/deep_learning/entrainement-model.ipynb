# %%
import cv2
import numpy as np
import requests
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import sys
import datetime
from tensorflow import keras
from tensorflow.keras.models import Model
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Pictures import & pre-processing

# %%
import pathlib

data_model = pathlib.Path("/content/drive/MyDrive/Jedha/Final_project/cars_pic/cars_model")
print(data_model)
# Out:
# /content/drive/MyDrive/Jedha/Final_project/cars_pic/cars_model

# %%
for item in data_model.iterdir():
  print(item)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-0c2266e2dafa> in <module>()
# ----> 1 for item in data_model.iterdir():
#       2   print(item)
#
# /usr/lib/python3.7/pathlib.py in iterdir(self)
#    1105         if self._closed:
#    1106             self._raise_closed()
# -> 1107         for name in self._accessor.listdir(self):
#    1108             if name in {'.', '..'}:
#    1109                 # Yielding a path object for these makes little sense
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Jedha/Final_project/cars_pic/cars_model'

# %%
# Creation an ImageDataGenerator object in order to use data augmentation on the cars pictures

img_generator = tf.keras.preprocessing.image.ImageDataGenerator(#rotation_range=90,
                                                                brightness_range=(0.5,1), 
                                                                #shear_range=0.2, 
                                                                #zoom_range=0.2,
                                                                channel_shift_range=0.2,
                                                                horizontal_flip=True,
                                                                vertical_flip=True,
                                                                rescale=1./255,
                                                                validation_split=0.2)

# %%
# Now we are able to set up the target image size and the batch size

img_generator_flow_train = img_generator.flow_from_directory(
    directory="/content/drive/MyDrive/Jedha/Final_project/cars_pic/cars_model",
    target_size=(224, 224),
    batch_size=32,
    shuffle=True,
    subset="training")

img_generator_flow_valid = img_generator.flow_from_directory(
    directory="/content/drive/MyDrive/Jedha/Final_project/cars_pic/cars_model",
    target_size=(224, 224),
    batch_size=32,
    shuffle=True,
    subset="validation")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-f9a1915f5ef2> in <module>()
#       6     batch_size=32,
#       7     shuffle=True,
# ----> 8     subset="training")
#       9
#      10 img_generator_flow_valid = img_generator.flow_from_directory(
#
# /usr/local/lib/python3.7/dist-packages/keras/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation)
#     990         follow_links=follow_links,
#     991         subset=subset,
# --> 992         interpolation=interpolation)
#     993
#     994   def flow_from_dataframe(self,
#
# /usr/local/lib/python3.7/dist-packages/keras/preprocessing/image.py in __init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, dtype)
#     408         subset=subset,
#     409         interpolation=interpolation,
# --> 410         **kwargs)
#     411
#     412
#
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/directory_iterator.py in __init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, dtype)
#     113         if not classes:
#     114             classes = []
# --> 115             for subdir in sorted(os.listdir(directory)):
#     116                 if os.path.isdir(os.path.join(directory, subdir)):
#     117                     classes.append(subdir)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Jedha/Final_project/cars_pic/cars_model'

# %%
# Let's visualize a group of images from the train set

from pathlib import Path

imgs, labels = next(iter(img_generator_flow_train))
for img, label in zip(imgs, labels):
  true_file_path = np.argmax(img_generator_flow_train.labels == tf.argmax(label))
  true_label_name = Path(img_generator_flow_train.filepaths[true_file_path]).parent.name
  print("Label :", true_label_name)
  plt.imshow(img)
  plt.show()
# Out:
# Label : 2008
# Label : C5 Aircross
# Label : 108
# Label : Berlingo
# Label : 308
# Label : 108
# Label : Aygo
# Label : 2008
# Label : Megane
# Label : Megane
# Label : Aygo
# Label : Golf
# Label : C3
# Label : Zoe
# Label : Corolla
# Label : Corolla
# Label : Berlingo
# Label : Tiguan
# Label : 208
# Label : 2008
# Label : Yaris
# Label : Twingo
# Label : Megane
# Label : 308
# Label : C5 Aircross
# Label : C3
# Label : Berlingo
# Label : Captur
# Label : C_HR
# Label : Up !
# Label : Clio
# Label : 108

# %% [markdown]
# # Header 1
# ## Header 2
# ...
#
# _italic_
# **bold**
# `code`

# %% [markdown]
# ## MobileNet trained model

# %%
# We'll use an already existing architecture: 'MobileNet' and use it to classify our cars pics

base_model = base_model = keras.applications.MobileNet(weights= 'imagenet' ,  
                                                  input_shape=( 224 , 224 , 3 ),
                                                  include_top= False )
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# 9420800/9406464 [==============================] - 0s 0us/step

# %%
# We can have a quick look at the architecture of our model

base_model.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         input_3[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 32) 288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 112, 112, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 112, 112, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 112, 112, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 112, 112, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 112, 112, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 112, 112, 96) 384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 112, 112, 96) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 113, 113, 96) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 56, 56, 96)   864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 56, 56, 96)   384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 56, 56, 96)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 56, 56, 24)   2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 56, 56, 24)   96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 56, 56, 144)  3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 56, 56, 144)  1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 56, 56, 144)  576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 56, 56, 144)  0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 56, 56, 24)   3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 56, 56, 24)   96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 56, 56, 24)   0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 56, 56, 144)  3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 57, 57, 144)  0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 28, 28, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 28, 28, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 28, 28, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 28, 28, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 28, 28, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 28, 28, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 28, 28, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 28, 28, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 28, 28, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 28, 28, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 28, 28, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 28, 28, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 28, 28, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 28, 28, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 29, 29, 192)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 14, 14, 192)  1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 14, 14, 192)  768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 14, 14, 192)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 14, 14, 64)   12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 14, 14, 64)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 14, 14, 384)  24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 14, 14, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 14, 14, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 14, 14, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 14, 14, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 14, 14, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 14, 14, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 14, 14, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 14, 14, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 14, 14, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 14, 14, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 14, 14, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 14, 14, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 14, 14, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 14, 14, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 14, 14, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 14, 14, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 14, 14, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 14, 14, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 14, 14, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 14, 14, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 14, 14, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 14, 14, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 14, 14, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 14, 14, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 14, 14, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 14, 14, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 14, 14, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 15, 15, 576)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 7, 7, 576)    5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 7, 7, 576)    2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)    0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 7, 7, 160)    92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 7, 7, 160)    640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 7, 7, 960)    153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 7, 7, 160)    153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 7, 7, 160)    640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 7, 7, 160)    0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 7, 7, 960)    153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 7, 7, 160)    153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 7, 7, 160)    640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 7, 7, 160)    0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 7, 7, 960)    153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 7, 7, 320)    307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 7, 7, 320)    1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 7, 7, 1280)   409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)   5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 7, 7, 1280)   0           Conv_1_bn[0][0]
# ==================================================================================================
# Total params: 2,257,984
# Trainable params: 2,223,872
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %%
# Now we'll freeze our model so that only the custom layers will train

base_model.trainable = False

# %%
# We removed the last layer to be able to adapt the model to our situation. So now let's to add our last layer.

model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalMaxPooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(len(set(img_generator_flow_train.labels)), activation="softmax")
])

# %%
# Let's create a learning rate schedule to decrease the learning rate as we train the model. 
initial_learning_rate = 0.001

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=1000,
    decay_rate=0.96,
    staircase=True)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = lr_schedule),
              loss = tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics = [tf.keras.metrics.CategoricalAccuracy()])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_224 (Functi (None, 7, 7, 1280)        2257984
# _________________________________________________________________
# global_max_pooling2d_2 (Glob (None, 1280)              0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 25)                32025
# =================================================================
# Total params: 2,290,009
# Trainable params: 32,025
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
# Now let's practice our model

model.fit(img_generator_flow_train, validation_data=img_generator_flow_valid, epochs=100)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4847: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`categorical_crossentropy` received `from_logits=True`, but '
# 82/82 [==============================] - 57s 655ms/step - loss: 5.3115 - categorical_accuracy: 0.1021 - val_loss: 3.9726 - val_categorical_accuracy: 0.1521
# Epoch 2/100
# 82/82 [==============================] - 51s 627ms/step - loss: 3.4883 - categorical_accuracy: 0.2281 - val_loss: 3.2949 - val_categorical_accuracy: 0.2479
# Epoch 3/100
# 82/82 [==============================] - 52s 631ms/step - loss: 2.8360 - categorical_accuracy: 0.3232 - val_loss: 2.8052 - val_categorical_accuracy: 0.3251
# Epoch 4/100
# 82/82 [==============================] - 52s 631ms/step - loss: 2.4145 - categorical_accuracy: 0.3860 - val_loss: 2.8143 - val_categorical_accuracy: 0.3143
# Epoch 5/100
# 82/82 [==============================] - 52s 638ms/step - loss: 2.1558 - categorical_accuracy: 0.4347 - val_loss: 2.5148 - val_categorical_accuracy: 0.3792
# Epoch 6/100
# 82/82 [==============================] - 54s 665ms/step - loss: 2.0011 - categorical_accuracy: 0.4645 - val_loss: 2.7593 - val_categorical_accuracy: 0.3637
# Epoch 7/100
# 82/82 [==============================] - 54s 664ms/step - loss: 1.8491 - categorical_accuracy: 0.5019 - val_loss: 2.5195 - val_categorical_accuracy: 0.4046
# Epoch 8/100
# 82/82 [==============================] - 54s 661ms/step - loss: 1.7234 - categorical_accuracy: 0.5344 - val_loss: 2.2665 - val_categorical_accuracy: 0.4278
# Epoch 9/100
# 82/82 [==============================] - 54s 657ms/step - loss: 1.5973 - categorical_accuracy: 0.5569 - val_loss: 2.2431 - val_categorical_accuracy: 0.4363
# Epoch 10/100
# 82/82 [==============================] - 54s 655ms/step - loss: 1.5270 - categorical_accuracy: 0.5678 - val_loss: 2.2665 - val_categorical_accuracy: 0.4340
# Epoch 11/100
# 82/82 [==============================] - 54s 657ms/step - loss: 1.3728 - categorical_accuracy: 0.6052 - val_loss: 2.1810 - val_categorical_accuracy: 0.4602
# Epoch 12/100
# 82/82 [==============================] - 53s 652ms/step - loss: 1.3318 - categorical_accuracy: 0.6153 - val_loss: 2.2282 - val_categorical_accuracy: 0.4448
# Epoch 13/100
# 82/82 [==============================] - 54s 653ms/step - loss: 1.2538 - categorical_accuracy: 0.6281 - val_loss: 2.1873 - val_categorical_accuracy: 0.4402
# Epoch 14/100
# 82/82 [==============================] - 53s 644ms/step - loss: 1.1945 - categorical_accuracy: 0.6380 - val_loss: 2.1472 - val_categorical_accuracy: 0.4463
# Epoch 15/100
# 82/82 [==============================] - 53s 642ms/step - loss: 1.1648 - categorical_accuracy: 0.6525 - val_loss: 2.1994 - val_categorical_accuracy: 0.4803
# Epoch 16/100
# 82/82 [==============================] - 53s 646ms/step - loss: 1.1415 - categorical_accuracy: 0.6657 - val_loss: 2.2712 - val_categorical_accuracy: 0.4247
# Epoch 17/100
# 82/82 [==============================] - 52s 640ms/step - loss: 1.0847 - categorical_accuracy: 0.6793 - val_loss: 2.1885 - val_categorical_accuracy: 0.4741
# Epoch 18/100
# 82/82 [==============================] - 53s 645ms/step - loss: 1.1256 - categorical_accuracy: 0.6703 - val_loss: 2.1877 - val_categorical_accuracy: 0.4741
# Epoch 19/100
# 82/82 [==============================] - 53s 649ms/step - loss: 1.0102 - categorical_accuracy: 0.6974 - val_loss: 2.0350 - val_categorical_accuracy: 0.4981
# Epoch 20/100
# 82/82 [==============================] - 53s 645ms/step - loss: 1.0117 - categorical_accuracy: 0.6985 - val_loss: 2.2576 - val_categorical_accuracy: 0.4579
# Epoch 21/100
# 82/82 [==============================] - 53s 646ms/step - loss: 0.9839 - categorical_accuracy: 0.7069 - val_loss: 2.1735 - val_categorical_accuracy: 0.4780
# Epoch 22/100
# 82/82 [==============================] - 53s 647ms/step - loss: 0.9681 - categorical_accuracy: 0.7117 - val_loss: 2.1495 - val_categorical_accuracy: 0.4764
# Epoch 23/100
# 82/82 [==============================] - 53s 646ms/step - loss: 0.9420 - categorical_accuracy: 0.7125 - val_loss: 2.2048 - val_categorical_accuracy: 0.4880
# Epoch 24/100
# 82/82 [==============================] - 53s 649ms/step - loss: 0.9035 - categorical_accuracy: 0.7293 - val_loss: 2.1891 - val_categorical_accuracy: 0.4903
# Epoch 25/100
# 82/82 [==============================] - 53s 641ms/step - loss: 0.8612 - categorical_accuracy: 0.7363 - val_loss: 2.0329 - val_categorical_accuracy: 0.5089
# Epoch 26/100
# 82/82 [==============================] - 52s 640ms/step - loss: 0.8306 - categorical_accuracy: 0.7411 - val_loss: 2.1118 - val_categorical_accuracy: 0.4927
# Epoch 27/100
# 82/82 [==============================] - 53s 646ms/step - loss: 0.7981 - categorical_accuracy: 0.7528 - val_loss: 2.0668 - val_categorical_accuracy: 0.5035
# Epoch 28/100
# 82/82 [==============================] - 52s 638ms/step - loss: 0.8594 - categorical_accuracy: 0.7404 - val_loss: 2.2338 - val_categorical_accuracy: 0.4934
# Epoch 29/100
# 82/82 [==============================] - 53s 642ms/step - loss: 0.7955 - categorical_accuracy: 0.7566 - val_loss: 2.1707 - val_categorical_accuracy: 0.4942
# Epoch 30/100
# 82/82 [==============================] - 53s 642ms/step - loss: 0.7837 - categorical_accuracy: 0.7583 - val_loss: 2.1652 - val_categorical_accuracy: 0.4927
# Epoch 31/100
# 82/82 [==============================] - 52s 639ms/step - loss: 0.7639 - categorical_accuracy: 0.7635 - val_loss: 1.9903 - val_categorical_accuracy: 0.5290
# Epoch 32/100
# 82/82 [==============================] - 52s 639ms/step - loss: 0.7370 - categorical_accuracy: 0.7692 - val_loss: 2.0810 - val_categorical_accuracy: 0.5143
# Epoch 33/100
# 82/82 [==============================] - 52s 639ms/step - loss: 0.7266 - categorical_accuracy: 0.7743 - val_loss: 2.2877 - val_categorical_accuracy: 0.4726
# Epoch 34/100
# 82/82 [==============================] - 53s 640ms/step - loss: 0.7574 - categorical_accuracy: 0.7663 - val_loss: 2.1952 - val_categorical_accuracy: 0.4988
# Epoch 35/100
# 82/82 [==============================] - 53s 644ms/step - loss: 0.7005 - categorical_accuracy: 0.7738 - val_loss: 2.0395 - val_categorical_accuracy: 0.5151
# Epoch 36/100
# 82/82 [==============================] - 54s 658ms/step - loss: 0.7251 - categorical_accuracy: 0.7755 - val_loss: 2.1928 - val_categorical_accuracy: 0.5166
# Epoch 37/100
# 82/82 [==============================] - 53s 652ms/step - loss: 0.6593 - categorical_accuracy: 0.7913 - val_loss: 2.0644 - val_categorical_accuracy: 0.5104
# Epoch 38/100
# 82/82 [==============================] - 53s 649ms/step - loss: 0.6958 - categorical_accuracy: 0.7824 - val_loss: 2.0584 - val_categorical_accuracy: 0.5012
# Epoch 39/100
# 82/82 [==============================] - 54s 653ms/step - loss: 0.6250 - categorical_accuracy: 0.8032 - val_loss: 2.2431 - val_categorical_accuracy: 0.4687
# Epoch 40/100
# 82/82 [==============================] - 53s 652ms/step - loss: 0.6744 - categorical_accuracy: 0.7826 - val_loss: 2.3737 - val_categorical_accuracy: 0.4849
# Epoch 41/100
# 82/82 [==============================] - 54s 658ms/step - loss: 0.6410 - categorical_accuracy: 0.7982 - val_loss: 2.2279 - val_categorical_accuracy: 0.4988
# Epoch 42/100
# 82/82 [==============================] - 54s 657ms/step - loss: 0.6384 - categorical_accuracy: 0.7965 - val_loss: 2.0905 - val_categorical_accuracy: 0.5212
# Epoch 43/100
# 82/82 [==============================] - 53s 652ms/step - loss: 0.6067 - categorical_accuracy: 0.8137 - val_loss: 2.1989 - val_categorical_accuracy: 0.5189
# Epoch 44/100
# 82/82 [==============================] - 53s 652ms/step - loss: 0.6225 - categorical_accuracy: 0.8051 - val_loss: 2.4214 - val_categorical_accuracy: 0.4849
# Epoch 45/100
# 82/82 [==============================] - 55s 667ms/step - loss: 0.6144 - categorical_accuracy: 0.8104 - val_loss: 2.2452 - val_categorical_accuracy: 0.5120
# Epoch 46/100
# 82/82 [==============================] - 55s 673ms/step - loss: 0.6044 - categorical_accuracy: 0.8020 - val_loss: 2.2670 - val_categorical_accuracy: 0.4965
# Epoch 47/100
# 82/82 [==============================] - 55s 673ms/step - loss: 0.5935 - categorical_accuracy: 0.8083 - val_loss: 2.1932 - val_categorical_accuracy: 0.5166
# Epoch 48/100
# 82/82 [==============================] - 54s 656ms/step - loss: 0.5833 - categorical_accuracy: 0.8114 - val_loss: 2.2828 - val_categorical_accuracy: 0.4996
# Epoch 49/100
# 82/82 [==============================] - 54s 659ms/step - loss: 0.6157 - categorical_accuracy: 0.8060 - val_loss: 2.1042 - val_categorical_accuracy: 0.5290
# Epoch 50/100
# 82/82 [==============================] - 53s 652ms/step - loss: 0.5571 - categorical_accuracy: 0.8200 - val_loss: 2.1797 - val_categorical_accuracy: 0.5251
# Epoch 51/100
# 82/82 [==============================] - 54s 656ms/step - loss: 0.5535 - categorical_accuracy: 0.8181 - val_loss: 2.1884 - val_categorical_accuracy: 0.5151
# Epoch 52/100
# 82/82 [==============================] - 54s 659ms/step - loss: 0.5614 - categorical_accuracy: 0.8253 - val_loss: 2.1412 - val_categorical_accuracy: 0.5158
# Epoch 53/100
# 82/82 [==============================] - 53s 651ms/step - loss: 0.5556 - categorical_accuracy: 0.8219 - val_loss: 2.1040 - val_categorical_accuracy: 0.5297
# Epoch 54/100
# 82/82 [==============================] - 53s 649ms/step - loss: 0.5452 - categorical_accuracy: 0.8268 - val_loss: 2.2814 - val_categorical_accuracy: 0.5151
# Epoch 55/100
# 82/82 [==============================] - 53s 649ms/step - loss: 0.5585 - categorical_accuracy: 0.8276 - val_loss: 2.1025 - val_categorical_accuracy: 0.5073
# Epoch 56/100
# 82/82 [==============================] - 53s 647ms/step - loss: 0.5553 - categorical_accuracy: 0.8228 - val_loss: 2.3195 - val_categorical_accuracy: 0.4958
# Epoch 57/100
# 82/82 [==============================] - 53s 642ms/step - loss: 0.5161 - categorical_accuracy: 0.8341 - val_loss: 2.1583 - val_categorical_accuracy: 0.5320
# Epoch 58/100
# 82/82 [==============================] - 53s 652ms/step - loss: 0.4796 - categorical_accuracy: 0.8457 - val_loss: 2.3044 - val_categorical_accuracy: 0.4981
# Epoch 59/100
# 82/82 [==============================] - 53s 643ms/step - loss: 0.5277 - categorical_accuracy: 0.8331 - val_loss: 2.3035 - val_categorical_accuracy: 0.5058
# Epoch 60/100
# 82/82 [==============================] - 53s 641ms/step - loss: 0.5790 - categorical_accuracy: 0.8108 - val_loss: 2.3462 - val_categorical_accuracy: 0.5019
# Epoch 61/100
# 82/82 [==============================] - 53s 642ms/step - loss: 0.5279 - categorical_accuracy: 0.8339 - val_loss: 2.2095 - val_categorical_accuracy: 0.5066
# Epoch 62/100
# 82/82 [==============================] - 53s 646ms/step - loss: 0.5115 - categorical_accuracy: 0.8366 - val_loss: 2.3106 - val_categorical_accuracy: 0.4981
# Epoch 63/100
# 82/82 [==============================] - 54s 653ms/step - loss: 0.4644 - categorical_accuracy: 0.8517 - val_loss: 2.3258 - val_categorical_accuracy: 0.5073
# Epoch 64/100
# 82/82 [==============================] - 53s 652ms/step - loss: 0.5205 - categorical_accuracy: 0.8312 - val_loss: 2.3948 - val_categorical_accuracy: 0.5019
# Epoch 65/100
# 82/82 [==============================] - 53s 648ms/step - loss: 0.4876 - categorical_accuracy: 0.8360 - val_loss: 2.2634 - val_categorical_accuracy: 0.5158
# Epoch 66/100
# 82/82 [==============================] - 53s 649ms/step - loss: 0.4779 - categorical_accuracy: 0.8414 - val_loss: 2.3119 - val_categorical_accuracy: 0.5066
# Epoch 67/100
# 82/82 [==============================] - 53s 649ms/step - loss: 0.4675 - categorical_accuracy: 0.8536 - val_loss: 2.3515 - val_categorical_accuracy: 0.5189
# Epoch 68/100
# 82/82 [==============================] - 53s 647ms/step - loss: 0.4645 - categorical_accuracy: 0.8478 - val_loss: 2.3594 - val_categorical_accuracy: 0.5004
# Epoch 69/100
# 82/82 [==============================] - 53s 644ms/step - loss: 0.4728 - categorical_accuracy: 0.8482 - val_loss: 2.3871 - val_categorical_accuracy: 0.5019
# Epoch 70/100
# 82/82 [==============================] - 53s 648ms/step - loss: 0.4676 - categorical_accuracy: 0.8463 - val_loss: 2.5306 - val_categorical_accuracy: 0.4873
# Epoch 71/100
# 82/82 [==============================] - 53s 648ms/step - loss: 0.4915 - categorical_accuracy: 0.8402 - val_loss: 2.3070 - val_categorical_accuracy: 0.5166
# Epoch 72/100
# 82/82 [==============================] - 53s 651ms/step - loss: 0.4488 - categorical_accuracy: 0.8530 - val_loss: 2.2626 - val_categorical_accuracy: 0.5066
# Epoch 73/100
# 82/82 [==============================] - 53s 642ms/step - loss: 0.3868 - categorical_accuracy: 0.8738 - val_loss: 2.3143 - val_categorical_accuracy: 0.5189
# Epoch 74/100
# 82/82 [==============================] - 53s 641ms/step - loss: 0.4482 - categorical_accuracy: 0.8549 - val_loss: 2.5232 - val_categorical_accuracy: 0.4873
# Epoch 75/100
# 82/82 [==============================] - 53s 646ms/step - loss: 0.4880 - categorical_accuracy: 0.8412 - val_loss: 2.3962 - val_categorical_accuracy: 0.5297
# Epoch 76/100
# 82/82 [==============================] - 53s 643ms/step - loss: 0.4724 - categorical_accuracy: 0.8452 - val_loss: 2.3080 - val_categorical_accuracy: 0.5266
# Epoch 77/100
# 82/82 [==============================] - 53s 643ms/step - loss: 0.4252 - categorical_accuracy: 0.8645 - val_loss: 2.3528 - val_categorical_accuracy: 0.5073
# Epoch 78/100
# 82/82 [==============================] - 52s 637ms/step - loss: 0.4146 - categorical_accuracy: 0.8643 - val_loss: 2.3035 - val_categorical_accuracy: 0.4934
# Epoch 79/100
# 82/82 [==============================] - 52s 636ms/step - loss: 0.4356 - categorical_accuracy: 0.8593 - val_loss: 2.3689 - val_categorical_accuracy: 0.5050
# Epoch 80/100
# 82/82 [==============================] - 52s 640ms/step - loss: 0.4382 - categorical_accuracy: 0.8543 - val_loss: 2.5032 - val_categorical_accuracy: 0.5004
# Epoch 81/100
# 82/82 [==============================] - 52s 641ms/step - loss: 0.4384 - categorical_accuracy: 0.8564 - val_loss: 2.4329 - val_categorical_accuracy: 0.5127
# Epoch 82/100
# 82/82 [==============================] - 53s 643ms/step - loss: 0.4428 - categorical_accuracy: 0.8543 - val_loss: 2.4490 - val_categorical_accuracy: 0.4965
# Epoch 83/100
# 82/82 [==============================] - 52s 638ms/step - loss: 0.4247 - categorical_accuracy: 0.8587 - val_loss: 2.2031 - val_categorical_accuracy: 0.5444
# Epoch 84/100
# 82/82 [==============================] - 52s 634ms/step - loss: 0.3811 - categorical_accuracy: 0.8755 - val_loss: 2.4886 - val_categorical_accuracy: 0.5166
# Epoch 85/100
# 82/82 [==============================] - 53s 641ms/step - loss: 0.4288 - categorical_accuracy: 0.8580 - val_loss: 2.3372 - val_categorical_accuracy: 0.5104
# Epoch 86/100
# 82/82 [==============================] - 53s 643ms/step - loss: 0.4288 - categorical_accuracy: 0.8582 - val_loss: 2.4602 - val_categorical_accuracy: 0.5004
# Epoch 87/100
# 82/82 [==============================] - 53s 643ms/step - loss: 0.4409 - categorical_accuracy: 0.8589 - val_loss: 2.6181 - val_categorical_accuracy: 0.4911
# Epoch 88/100
# 82/82 [==============================] - 54s 663ms/step - loss: 0.4209 - categorical_accuracy: 0.8572 - val_loss: 2.5032 - val_categorical_accuracy: 0.5174
# Epoch 89/100
# 82/82 [==============================] - 54s 655ms/step - loss: 0.3986 - categorical_accuracy: 0.8683 - val_loss: 2.5245 - val_categorical_accuracy: 0.5035
# Epoch 90/100
# 82/82 [==============================] - 53s 644ms/step - loss: 0.3984 - categorical_accuracy: 0.8681 - val_loss: 2.3046 - val_categorical_accuracy: 0.5259
# Epoch 91/100
# 82/82 [==============================] - 53s 647ms/step - loss: 0.4099 - categorical_accuracy: 0.8624 - val_loss: 2.3750 - val_categorical_accuracy: 0.5127
# Epoch 92/100
# 82/82 [==============================] - 53s 643ms/step - loss: 0.3677 - categorical_accuracy: 0.8841 - val_loss: 2.4708 - val_categorical_accuracy: 0.5097
# Epoch 93/100
# 82/82 [==============================] - 54s 655ms/step - loss: 0.3737 - categorical_accuracy: 0.8792 - val_loss: 2.5093 - val_categorical_accuracy: 0.5151
# Epoch 94/100
# 82/82 [==============================] - 55s 666ms/step - loss: 0.3863 - categorical_accuracy: 0.8740 - val_loss: 2.4528 - val_categorical_accuracy: 0.5004
# Epoch 95/100
# 82/82 [==============================] - 54s 653ms/step - loss: 0.3975 - categorical_accuracy: 0.8723 - val_loss: 2.5701 - val_categorical_accuracy: 0.4950
# Epoch 96/100
# 82/82 [==============================] - 54s 658ms/step - loss: 0.4074 - categorical_accuracy: 0.8641 - val_loss: 2.5075 - val_categorical_accuracy: 0.5143
# Epoch 97/100
# 82/82 [==============================] - 54s 659ms/step - loss: 0.3859 - categorical_accuracy: 0.8801 - val_loss: 2.3946 - val_categorical_accuracy: 0.5328
# Epoch 98/100
# 82/82 [==============================] - 54s 662ms/step - loss: 0.3940 - categorical_accuracy: 0.8660 - val_loss: 2.5543 - val_categorical_accuracy: 0.5097
# Epoch 99/100
# 82/82 [==============================] - 53s 651ms/step - loss: 0.3543 - categorical_accuracy: 0.8792 - val_loss: 2.3823 - val_categorical_accuracy: 0.5243
# Epoch 100/100
# 82/82 [==============================] - 53s 649ms/step - loss: 0.3483 - categorical_accuracy: 0.8864 - val_loss: 2.5031 - val_categorical_accuracy: 0.5073

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_224 (Functi (None, 7, 7, 1280)        2257984
# _________________________________________________________________
# global_max_pooling2d_2 (Glob (None, 1280)              0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 25)                32025
# =================================================================
# Total params: 2,290,009
# Trainable params: 32,025
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %% [markdown]
# ## MobileNetV2 trained model

# %%
# We'll use an already existing architecture: 'MobileNet' and use it to classify our cars pics

base_model = base_model = keras.applications.MobileNetV2(weights= 'imagenet' ,  
                                                  input_shape=( 224 , 224 , 3 ),
                                                  include_top= False )

# %%
# We can have a quick look at the architecture of our model

base_model.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         input_5[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 32) 288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 112, 112, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 112, 112, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 112, 112, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 112, 112, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 112, 112, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 112, 112, 96) 384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 112, 112, 96) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 113, 113, 96) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 56, 56, 96)   864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 56, 56, 96)   384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 56, 56, 96)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 56, 56, 24)   2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 56, 56, 24)   96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 56, 56, 144)  3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 56, 56, 144)  1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 56, 56, 144)  576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 56, 56, 144)  0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 56, 56, 24)   3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 56, 56, 24)   96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 56, 56, 24)   0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 56, 56, 144)  3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 57, 57, 144)  0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 28, 28, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 28, 28, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 28, 28, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 28, 28, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 28, 28, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 28, 28, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 28, 28, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 28, 28, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 28, 28, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 28, 28, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 28, 28, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 28, 28, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 28, 28, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 28, 28, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 29, 29, 192)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 14, 14, 192)  1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 14, 14, 192)  768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 14, 14, 192)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 14, 14, 64)   12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 14, 14, 64)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 14, 14, 384)  24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 14, 14, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 14, 14, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 14, 14, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 14, 14, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 14, 14, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 14, 14, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 14, 14, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 14, 14, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 14, 14, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 14, 14, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 14, 14, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 14, 14, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 14, 14, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 14, 14, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 14, 14, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 14, 14, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 14, 14, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 14, 14, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 14, 14, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 14, 14, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 14, 14, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 14, 14, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 14, 14, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 14, 14, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 14, 14, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 14, 14, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 14, 14, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 15, 15, 576)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 7, 7, 576)    5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 7, 7, 576)    2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)    0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 7, 7, 160)    92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 7, 7, 160)    640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 7, 7, 960)    153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 7, 7, 160)    153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 7, 7, 160)    640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 7, 7, 160)    0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 7, 7, 960)    153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 7, 7, 160)    153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 7, 7, 160)    640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 7, 7, 160)    0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 7, 7, 960)    153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 7, 7, 320)    307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 7, 7, 320)    1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 7, 7, 1280)   409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)   5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 7, 7, 1280)   0           Conv_1_bn[0][0]
# ==================================================================================================
# Total params: 2,257,984
# Trainable params: 2,223,872
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %%
# Now we'll freeze our model so that only the custom layers will train

base_model.trainable = False

# %%
# We removed the last layer to be able to adapt the model to our situation. So now let's to add our last layer.

model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalMaxPooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(len(set(img_generator_flow_train.labels)), activation="softmax")
])

# %%
# Let's create a learning rate schedule to decrease the learning rate as we train the model. 
initial_learning_rate = 0.001

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=1000,
    decay_rate=0.96,
    staircase=True)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = lr_schedule),
              loss = tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics = [tf.keras.metrics.CategoricalAccuracy()])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_224 (Functi (None, 7, 7, 1280)        2257984
# _________________________________________________________________
# global_max_pooling2d_3 (Glob (None, 1280)              0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 25)                32025
# =================================================================
# Total params: 2,290,009
# Trainable params: 32,025
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
# Now let's practice our model

model.fit(img_generator_flow_train, validation_data=img_generator_flow_valid, epochs=50)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4847: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`categorical_crossentropy` received `from_logits=True`, but '
# 164/164 [==============================] - 68s 390ms/step - loss: 5.1010 - categorical_accuracy: 0.1247 - val_loss: 3.7171 - val_categorical_accuracy: 0.2162
# Epoch 2/100
# 164/164 [==============================] - 62s 381ms/step - loss: 3.2554 - categorical_accuracy: 0.2827 - val_loss: 3.0454 - val_categorical_accuracy: 0.3104
# Epoch 3/100
# 164/164 [==============================] - 64s 392ms/step - loss: 2.7112 - categorical_accuracy: 0.3627 - val_loss: 3.3821 - val_categorical_accuracy: 0.3143
# Epoch 4/100
# 164/164 [==============================] - 65s 394ms/step - loss: 2.3705 - categorical_accuracy: 0.4198 - val_loss: 2.8577 - val_categorical_accuracy: 0.3629
# Epoch 5/100
# 164/164 [==============================] - 64s 393ms/step - loss: 2.0797 - categorical_accuracy: 0.4779 - val_loss: 2.5602 - val_categorical_accuracy: 0.4224
# Epoch 6/100
# 164/164 [==============================] - 64s 393ms/step - loss: 1.8406 - categorical_accuracy: 0.5214 - val_loss: 2.4200 - val_categorical_accuracy: 0.4494
# Epoch 7/100
# 164/164 [==============================] - 65s 395ms/step - loss: 1.7817 - categorical_accuracy: 0.5305 - val_loss: 2.4047 - val_categorical_accuracy: 0.4394
# Epoch 8/100
# 164/164 [==============================] - 65s 394ms/step - loss: 1.6387 - categorical_accuracy: 0.5613 - val_loss: 2.4994 - val_categorical_accuracy: 0.4193
# Epoch 9/100
# 164/164 [==============================] - 64s 392ms/step - loss: 1.5732 - categorical_accuracy: 0.5760 - val_loss: 2.5307 - val_categorical_accuracy: 0.4456
# Epoch 10/100
# 164/164 [==============================] - 64s 391ms/step - loss: 1.4726 - categorical_accuracy: 0.5985 - val_loss: 2.5575 - val_categorical_accuracy: 0.4232
# Epoch 11/100
# 164/164 [==============================] - 64s 393ms/step - loss: 1.4011 - categorical_accuracy: 0.6126 - val_loss: 2.2428 - val_categorical_accuracy: 0.4680
# Epoch 12/100
# 164/164 [==============================] - 64s 392ms/step - loss: 1.2302 - categorical_accuracy: 0.6495 - val_loss: 2.2509 - val_categorical_accuracy: 0.4803
# Epoch 13/100
# 164/164 [==============================] - 64s 391ms/step - loss: 1.2327 - categorical_accuracy: 0.6522 - val_loss: 2.2765 - val_categorical_accuracy: 0.4625
# Epoch 14/100
# 164/164 [==============================] - 65s 394ms/step - loss: 1.1937 - categorical_accuracy: 0.6592 - val_loss: 2.4518 - val_categorical_accuracy: 0.4409
# Epoch 15/100
# 164/164 [==============================] - 65s 394ms/step - loss: 1.2263 - categorical_accuracy: 0.6508 - val_loss: 2.3288 - val_categorical_accuracy: 0.4795
# Epoch 16/100
# 164/164 [==============================] - 64s 393ms/step - loss: 1.1272 - categorical_accuracy: 0.6758 - val_loss: 2.6066 - val_categorical_accuracy: 0.4502
# Epoch 17/100
# 164/164 [==============================] - 64s 392ms/step - loss: 1.0723 - categorical_accuracy: 0.6844 - val_loss: 2.3652 - val_categorical_accuracy: 0.4741
# Epoch 18/100
# 164/164 [==============================] - 64s 393ms/step - loss: 1.0162 - categorical_accuracy: 0.7037 - val_loss: 2.3100 - val_categorical_accuracy: 0.4819
# Epoch 19/100
# 164/164 [==============================] - 64s 392ms/step - loss: 0.9843 - categorical_accuracy: 0.7188 - val_loss: 2.3475 - val_categorical_accuracy: 0.4834
# Epoch 20/100
# 164/164 [==============================] - 64s 392ms/step - loss: 0.9897 - categorical_accuracy: 0.7182 - val_loss: 2.3338 - val_categorical_accuracy: 0.4880
# Epoch 21/100
# 164/164 [==============================] - 64s 393ms/step - loss: 0.9416 - categorical_accuracy: 0.7171 - val_loss: 2.3355 - val_categorical_accuracy: 0.4880
# Epoch 22/100
# 164/164 [==============================] - 64s 393ms/step - loss: 0.9808 - categorical_accuracy: 0.7068 - val_loss: 2.2548 - val_categorical_accuracy: 0.4965
# Epoch 23/100
# 164/164 [==============================] - 64s 393ms/step - loss: 0.8986 - categorical_accuracy: 0.7363 - val_loss: 2.3691 - val_categorical_accuracy: 0.4880
# Epoch 24/100
# 164/164 [==============================] - 64s 392ms/step - loss: 0.8898 - categorical_accuracy: 0.7300 - val_loss: 2.4002 - val_categorical_accuracy: 0.4903
# Epoch 25/100
# 164/164 [==============================] - 64s 393ms/step - loss: 0.8691 - categorical_accuracy: 0.7415 - val_loss: 2.5235 - val_categorical_accuracy: 0.4834
# Epoch 26/100
# 164/164 [==============================] - 65s 394ms/step - loss: 0.8370 - categorical_accuracy: 0.7493 - val_loss: 2.2800 - val_categorical_accuracy: 0.4927
# Epoch 27/100
# 164/164 [==============================] - 65s 393ms/step - loss: 0.7973 - categorical_accuracy: 0.7553 - val_loss: 2.6180 - val_categorical_accuracy: 0.4571
# Epoch 28/100
# 164/164 [==============================] - 65s 393ms/step - loss: 0.8470 - categorical_accuracy: 0.7423 - val_loss: 2.5846 - val_categorical_accuracy: 0.4703
# Epoch 29/100
# 164/164 [==============================] - 63s 385ms/step - loss: 0.7794 - categorical_accuracy: 0.7642 - val_loss: 2.4288 - val_categorical_accuracy: 0.5120
# Epoch 30/100
# 164/164 [==============================] - 63s 383ms/step - loss: 0.8136 - categorical_accuracy: 0.7510 - val_loss: 2.4890 - val_categorical_accuracy: 0.4772
# Epoch 31/100
# 164/164 [==============================] - 65s 393ms/step - loss: 0.7843 - categorical_accuracy: 0.7604 - val_loss: 2.3791 - val_categorical_accuracy: 0.4942
# Epoch 32/100
# 164/164 [==============================] - 65s 394ms/step - loss: 0.7582 - categorical_accuracy: 0.7673 - val_loss: 2.5153 - val_categorical_accuracy: 0.4757
# Epoch 33/100
# 164/164 [==============================] - 65s 396ms/step - loss: 0.6827 - categorical_accuracy: 0.7900 - val_loss: 2.2867 - val_categorical_accuracy: 0.5081
# Epoch 34/100
# 164/164 [==============================] - 64s 393ms/step - loss: 0.6749 - categorical_accuracy: 0.7917 - val_loss: 2.3717 - val_categorical_accuracy: 0.5004
# Epoch 35/100
# 164/164 [==============================] - 65s 394ms/step - loss: 0.7112 - categorical_accuracy: 0.7791 - val_loss: 2.4043 - val_categorical_accuracy: 0.4911
# Epoch 36/100
# 164/164 [==============================] - 65s 394ms/step - loss: 0.7448 - categorical_accuracy: 0.7768 - val_loss: 2.4107 - val_categorical_accuracy: 0.5066
# Epoch 37/100
# 164/164 [==============================] - 65s 395ms/step - loss: 0.6615 - categorical_accuracy: 0.7873 - val_loss: 2.5345 - val_categorical_accuracy: 0.4896
# Epoch 38/100
# 164/164 [==============================] - 64s 392ms/step - loss: 0.6687 - categorical_accuracy: 0.7911 - val_loss: 2.5038 - val_categorical_accuracy: 0.4826
# Epoch 39/100
# 164/164 [==============================] - 65s 396ms/step - loss: 0.6460 - categorical_accuracy: 0.7929 - val_loss: 2.3306 - val_categorical_accuracy: 0.5143
# Epoch 40/100
# 164/164 [==============================] - 64s 393ms/step - loss: 0.6404 - categorical_accuracy: 0.7982 - val_loss: 2.4227 - val_categorical_accuracy: 0.4857
# Epoch 41/100
# 164/164 [==============================] - 65s 394ms/step - loss: 0.6684 - categorical_accuracy: 0.7890 - val_loss: 2.6618 - val_categorical_accuracy: 0.4788
# Epoch 42/100
# 164/164 [==============================] - 64s 393ms/step - loss: 0.6550 - categorical_accuracy: 0.7999 - val_loss: 2.5603 - val_categorical_accuracy: 0.4880
# Epoch 43/100
# 164/164 [==============================] - 64s 392ms/step - loss: 0.6174 - categorical_accuracy: 0.8095 - val_loss: 2.4392 - val_categorical_accuracy: 0.5089
# Epoch 44/100
# 164/164 [==============================] - 65s 394ms/step - loss: 0.6048 - categorical_accuracy: 0.8139 - val_loss: 2.3309 - val_categorical_accuracy: 0.5066
# Epoch 45/100
# 164/164 [==============================] - 65s 393ms/step - loss: 0.6142 - categorical_accuracy: 0.8058 - val_loss: 2.5622 - val_categorical_accuracy: 0.4919
# Epoch 46/100
# 164/164 [==============================] - 64s 392ms/step - loss: 0.5908 - categorical_accuracy: 0.8179 - val_loss: 2.4601 - val_categorical_accuracy: 0.5220
# Epoch 47/100
# 164/164 [==============================] - 64s 393ms/step - loss: 0.6084 - categorical_accuracy: 0.8070 - val_loss: 2.5575 - val_categorical_accuracy: 0.4981
# Epoch 48/100
# 164/164 [==============================] - 65s 393ms/step - loss: 0.5709 - categorical_accuracy: 0.8238 - val_loss: 2.5239 - val_categorical_accuracy: 0.4981
# Epoch 49/100
# 164/164 [==============================] - 65s 394ms/step - loss: 0.5808 - categorical_accuracy: 0.8183 - val_loss: 2.5601 - val_categorical_accuracy: 0.4981
# Epoch 50/100
# 164/164 [==============================] - 65s 393ms/step - loss: 0.5908 - categorical_accuracy: 0.8099 - val_loss: 2.5346 - val_categorical_accuracy: 0.5081
# Epoch 51/100
# 164/164 [==============================] - 64s 393ms/step - loss: 0.5861 - categorical_accuracy: 0.8144 - val_loss: 2.3942 - val_categorical_accuracy: 0.5127
# Epoch 52/100
# 164/164 [==============================] - 65s 393ms/step - loss: 0.5355 - categorical_accuracy: 0.8268 - val_loss: 2.6315 - val_categorical_accuracy: 0.4726
# Epoch 53/100
# 164/164 [==============================] - 65s 394ms/step - loss: 0.5545 - categorical_accuracy: 0.8274 - val_loss: 2.5658 - val_categorical_accuracy: 0.4934
# Epoch 54/100
# 164/164 [==============================] - 64s 393ms/step - loss: 0.5469 - categorical_accuracy: 0.8274 - val_loss: 2.4623 - val_categorical_accuracy: 0.5305
# Epoch 55/100
# 164/164 [==============================] - 65s 394ms/step - loss: 0.5264 - categorical_accuracy: 0.8314 - val_loss: 2.6013 - val_categorical_accuracy: 0.5097
# Epoch 56/100
# 164/164 [==============================] - 64s 391ms/step - loss: 0.5527 - categorical_accuracy: 0.8249 - val_loss: 2.4849 - val_categorical_accuracy: 0.5205
# Epoch 57/100
# 164/164 [==============================] - 62s 380ms/step - loss: 0.5077 - categorical_accuracy: 0.8274 - val_loss: 2.4576 - val_categorical_accuracy: 0.5120
# Epoch 58/100
# 164/164 [==============================] - 65s 395ms/step - loss: 0.5150 - categorical_accuracy: 0.8368 - val_loss: 2.5014 - val_categorical_accuracy: 0.5243
# Epoch 59/100
# 164/164 [==============================] - 65s 394ms/step - loss: 0.5555 - categorical_accuracy: 0.8202 - val_loss: 2.7233 - val_categorical_accuracy: 0.4958
# Epoch 60/100
# 164/164 [==============================] - 65s 394ms/step - loss: 0.4917 - categorical_accuracy: 0.8387 - val_loss: 2.5832 - val_categorical_accuracy: 0.5174
# Epoch 61/100
# 164/164 [==============================] - 65s 394ms/step - loss: 0.5482 - categorical_accuracy: 0.8242 - val_loss: 2.6513 - val_categorical_accuracy: 0.5004
# Epoch 62/100
# 164/164 [==============================] - 65s 394ms/step - loss: 0.5109 - categorical_accuracy: 0.8343 - val_loss: 2.7985 - val_categorical_accuracy: 0.4981
# Epoch 63/100
# 164/164 [==============================] - 65s 396ms/step - loss: 0.4779 - categorical_accuracy: 0.8444 - val_loss: 2.5389 - val_categorical_accuracy: 0.5035
# Epoch 64/100
# 164/164 [==============================] - 65s 398ms/step - loss: 0.4920 - categorical_accuracy: 0.8398 - val_loss: 2.6950 - val_categorical_accuracy: 0.4919
# Epoch 65/100
# 164/164 [==============================] - 65s 399ms/step - loss: 0.4643 - categorical_accuracy: 0.8532 - val_loss: 2.5001 - val_categorical_accuracy: 0.5228
# Epoch 66/100
# 164/164 [==============================] - 65s 398ms/step - loss: 0.5109 - categorical_accuracy: 0.8326 - val_loss: 2.6233 - val_categorical_accuracy: 0.5035
# Epoch 67/100
# 164/164 [==============================] - 65s 398ms/step - loss: 0.4887 - categorical_accuracy: 0.8389 - val_loss: 2.6674 - val_categorical_accuracy: 0.5073
# Epoch 68/100
# 164/164 [==============================] - 65s 398ms/step - loss: 0.4436 - categorical_accuracy: 0.8534 - val_loss: 2.6143 - val_categorical_accuracy: 0.4965
# Epoch 69/100
# 164/164 [==============================] - 65s 397ms/step - loss: 0.4772 - categorical_accuracy: 0.8471 - val_loss: 2.7110 - val_categorical_accuracy: 0.4888
# Epoch 70/100
# 164/164 [==============================] - 65s 395ms/step - loss: 0.4797 - categorical_accuracy: 0.8440 - val_loss: 2.6928 - val_categorical_accuracy: 0.5035
# Epoch 71/100
# 164/164 [==============================] - 65s 394ms/step - loss: 0.4641 - categorical_accuracy: 0.8484 - val_loss: 2.5985 - val_categorical_accuracy: 0.5012
# Epoch 72/100
# 164/164 [==============================] - 65s 395ms/step - loss: 0.4482 - categorical_accuracy: 0.8517 - val_loss: 2.8033 - val_categorical_accuracy: 0.4888
# Epoch 73/100
# 164/164 [==============================] - 64s 393ms/step - loss: 0.4403 - categorical_accuracy: 0.8559 - val_loss: 2.4461 - val_categorical_accuracy: 0.5305
# Epoch 74/100
# 164/164 [==============================] - 65s 395ms/step - loss: 0.4771 - categorical_accuracy: 0.8454 - val_loss: 2.6482 - val_categorical_accuracy: 0.4934
# Epoch 75/100
# 164/164 [==============================] - 65s 394ms/step - loss: 0.4120 - categorical_accuracy: 0.8671 - val_loss: 2.5901 - val_categorical_accuracy: 0.5344
# Epoch 76/100
# 164/164 [==============================] - 65s 394ms/step - loss: 0.4220 - categorical_accuracy: 0.8610 - val_loss: 2.8192 - val_categorical_accuracy: 0.4981
# Epoch 77/100
# 164/164 [==============================] - 65s 395ms/step - loss: 0.4184 - categorical_accuracy: 0.8538 - val_loss: 2.6697 - val_categorical_accuracy: 0.5181
# Epoch 78/100
# 164/164 [==============================] - 65s 394ms/step - loss: 0.4178 - categorical_accuracy: 0.8582 - val_loss: 2.7291 - val_categorical_accuracy: 0.5004
# Epoch 79/100
# 164/164 [==============================] - 65s 394ms/step - loss: 0.3729 - categorical_accuracy: 0.8750 - val_loss: 2.6346 - val_categorical_accuracy: 0.5066
# Epoch 80/100
# 164/164 [==============================] - 65s 394ms/step - loss: 0.4410 - categorical_accuracy: 0.8601 - val_loss: 2.7680 - val_categorical_accuracy: 0.5120
# Epoch 81/100
# 164/164 [==============================] - 65s 394ms/step - loss: 0.4087 - categorical_accuracy: 0.8641 - val_loss: 2.8565 - val_categorical_accuracy: 0.4958
# Epoch 82/100
# 164/164 [==============================] - 65s 395ms/step - loss: 0.4351 - categorical_accuracy: 0.8536 - val_loss: 2.6860 - val_categorical_accuracy: 0.5050
# Epoch 83/100
# 164/164 [==============================] - 65s 394ms/step - loss: 0.3879 - categorical_accuracy: 0.8776 - val_loss: 2.7335 - val_categorical_accuracy: 0.5066
# Epoch 84/100
# 164/164 [==============================] - 64s 389ms/step - loss: 0.3875 - categorical_accuracy: 0.8717 - val_loss: 2.6557 - val_categorical_accuracy: 0.5143
# Epoch 85/100
# 164/164 [==============================] - 62s 379ms/step - loss: 0.3896 - categorical_accuracy: 0.8729 - val_loss: 2.8089 - val_categorical_accuracy: 0.5205
# Epoch 86/100
# 164/164 [==============================] - 64s 393ms/step - loss: 0.4038 - categorical_accuracy: 0.8645 - val_loss: 2.6756 - val_categorical_accuracy: 0.5290
# Epoch 87/100
# 164/164 [==============================] - 65s 396ms/step - loss: 0.3827 - categorical_accuracy: 0.8711 - val_loss: 2.5368 - val_categorical_accuracy: 0.5189
# Epoch 88/100
# 164/164 [==============================] - 64s 393ms/step - loss: 0.3795 - categorical_accuracy: 0.8711 - val_loss: 2.7071 - val_categorical_accuracy: 0.5120
# Epoch 89/100
# 164/164 [==============================] - 65s 394ms/step - loss: 0.3714 - categorical_accuracy: 0.8767 - val_loss: 2.8066 - val_categorical_accuracy: 0.5019
# Epoch 90/100
# 164/164 [==============================] - 65s 394ms/step - loss: 0.3627 - categorical_accuracy: 0.8795 - val_loss: 2.5909 - val_categorical_accuracy: 0.5042
# Epoch 91/100
# 164/164 [==============================] - 65s 394ms/step - loss: 0.3852 - categorical_accuracy: 0.8715 - val_loss: 2.8067 - val_categorical_accuracy: 0.4819
# Epoch 92/100
# 164/164 [==============================] - 65s 394ms/step - loss: 0.3755 - categorical_accuracy: 0.8729 - val_loss: 2.7576 - val_categorical_accuracy: 0.5089
# Epoch 93/100
# 164/164 [==============================] - 65s 396ms/step - loss: 0.3538 - categorical_accuracy: 0.8885 - val_loss: 2.7785 - val_categorical_accuracy: 0.4942
# Epoch 94/100
# 164/164 [==============================] - 65s 394ms/step - loss: 0.3738 - categorical_accuracy: 0.8753 - val_loss: 2.9037 - val_categorical_accuracy: 0.4988
# Epoch 95/100
# 164/164 [==============================] - 65s 395ms/step - loss: 0.3192 - categorical_accuracy: 0.8906 - val_loss: 2.7955 - val_categorical_accuracy: 0.5073
# Epoch 96/100
# 164/164 [==============================] - 64s 393ms/step - loss: 0.3473 - categorical_accuracy: 0.8849 - val_loss: 2.7027 - val_categorical_accuracy: 0.5127
# Epoch 97/100
# 164/164 [==============================] - 65s 396ms/step - loss: 0.3711 - categorical_accuracy: 0.8746 - val_loss: 2.6485 - val_categorical_accuracy: 0.5143
# Epoch 98/100
# 164/164 [==============================] - 66s 400ms/step - loss: 0.3482 - categorical_accuracy: 0.8799 - val_loss: 3.0142 - val_categorical_accuracy: 0.4764
# Epoch 99/100
# 164/164 [==============================] - 65s 399ms/step - loss: 0.3245 - categorical_accuracy: 0.8918 - val_loss: 2.7312 - val_categorical_accuracy: 0.5050
# Epoch 100/100
# 164/164 [==============================] - 65s 397ms/step - loss: 0.3282 - categorical_accuracy: 0.8879 - val_loss: 2.7914 - val_categorical_accuracy: 0.5135

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_224 (Functi (None, 7, 7, 1280)        2257984
# _________________________________________________________________
# global_max_pooling2d_2 (Glob (None, 1280)              0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 25)                32025
# =================================================================
# Total params: 2,290,009
# Trainable params: 32,025
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %% [markdown]
# ## VGG19 trained model

# %%
# We'll use an already existing architecture: 'MobileNet' and use it to classify our cars pics

base_model = base_model = keras.applications.VGG19(weights= 'imagenet' ,  
                                                  input_shape=( 224 , 224 , 3 ),
                                                  include_top= False )

# %%
# We can have a quick look at the architecture of our model

base_model.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Now we'll freeze our model so that only the custom layers will train

base_model.trainable = False

# %%
# We removed the last layer to be able to adapt the model to our situation. So now let's to add our last layer.

model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalMaxPooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(len(set(img_generator_flow_train.labels)), activation="softmax")
])

# %%
# Let's create a learning rate schedule to decrease the learning rate as we train the model. 
initial_learning_rate = 0.001

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=1000,
    decay_rate=0.96,
    staircase=True)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = lr_schedule),
              loss = tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics = [tf.keras.metrics.CategoricalAccuracy()])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Functional)           (None, 7, 7, 512)         20024384
# _________________________________________________________________
# global_max_pooling2d_2 (Glob (None, 512)               0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 25)                12825
# =================================================================
# Total params: 20,037,209
# Trainable params: 12,825
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
# Now let's practice our model

model.fit(img_generator_flow_train, validation_data=img_generator_flow_valid, epochs=50)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4847: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`categorical_crossentropy` received `from_logits=True`, but '
# 164/164 [==============================] - 92s 492ms/step - loss: 3.1755 - categorical_accuracy: 0.0937 - val_loss: 2.9846 - val_categorical_accuracy: 0.1498
# Epoch 2/50
# 164/164 [==============================] - 74s 449ms/step - loss: 2.8404 - categorical_accuracy: 0.1894 - val_loss: 2.7979 - val_categorical_accuracy: 0.1876
# Epoch 3/50
# 164/164 [==============================] - 73s 445ms/step - loss: 2.6323 - categorical_accuracy: 0.2629 - val_loss: 2.6574 - val_categorical_accuracy: 0.2625
# Epoch 4/50
# 164/164 [==============================] - 73s 444ms/step - loss: 2.4776 - categorical_accuracy: 0.3127 - val_loss: 2.5261 - val_categorical_accuracy: 0.2996
# Epoch 5/50
# 164/164 [==============================] - 73s 445ms/step - loss: 2.3489 - categorical_accuracy: 0.3429 - val_loss: 2.4342 - val_categorical_accuracy: 0.3127
# Epoch 6/50
# 164/164 [==============================] - 73s 446ms/step - loss: 2.2526 - categorical_accuracy: 0.3795 - val_loss: 2.3444 - val_categorical_accuracy: 0.3529
# Epoch 7/50
# 164/164 [==============================] - 73s 447ms/step - loss: 2.1707 - categorical_accuracy: 0.3981 - val_loss: 2.3614 - val_categorical_accuracy: 0.3421
# Epoch 8/50
# 164/164 [==============================] - 75s 454ms/step - loss: 2.0955 - categorical_accuracy: 0.4286 - val_loss: 2.2676 - val_categorical_accuracy: 0.3598
# Epoch 9/50
# 164/164 [==============================] - 74s 450ms/step - loss: 2.0282 - categorical_accuracy: 0.4452 - val_loss: 2.1970 - val_categorical_accuracy: 0.3861
# Epoch 10/50
# 164/164 [==============================] - 74s 448ms/step - loss: 1.9780 - categorical_accuracy: 0.4500 - val_loss: 2.1689 - val_categorical_accuracy: 0.3985
# Epoch 11/50
# 164/164 [==============================] - 73s 446ms/step - loss: 1.9323 - categorical_accuracy: 0.4693 - val_loss: 2.1270 - val_categorical_accuracy: 0.3961
# Epoch 12/50
# 164/164 [==============================] - 73s 447ms/step - loss: 1.8852 - categorical_accuracy: 0.4824 - val_loss: 2.0760 - val_categorical_accuracy: 0.4154
# Epoch 13/50
# 164/164 [==============================] - 73s 447ms/step - loss: 1.8536 - categorical_accuracy: 0.4880 - val_loss: 2.1003 - val_categorical_accuracy: 0.4031
# Epoch 14/50
# 164/164 [==============================] - 73s 445ms/step - loss: 1.8098 - categorical_accuracy: 0.5010 - val_loss: 2.0528 - val_categorical_accuracy: 0.4170
# Epoch 15/50
# 164/164 [==============================] - 73s 447ms/step - loss: 1.7683 - categorical_accuracy: 0.5136 - val_loss: 2.0578 - val_categorical_accuracy: 0.4309
# Epoch 16/50
# 164/164 [==============================] - 74s 448ms/step - loss: 1.7374 - categorical_accuracy: 0.5248 - val_loss: 2.0012 - val_categorical_accuracy: 0.4239
# Epoch 17/50
# 164/164 [==============================] - 74s 447ms/step - loss: 1.7204 - categorical_accuracy: 0.5275 - val_loss: 1.9670 - val_categorical_accuracy: 0.4440
# Epoch 18/50
# 164/164 [==============================] - 74s 449ms/step - loss: 1.7048 - categorical_accuracy: 0.5304 - val_loss: 1.9922 - val_categorical_accuracy: 0.4278
# Epoch 19/50
# 164/164 [==============================] - 72s 436ms/step - loss: 1.6687 - categorical_accuracy: 0.5347 - val_loss: 1.9557 - val_categorical_accuracy: 0.4440
# Epoch 20/50
# 164/164 [==============================] - 74s 451ms/step - loss: 1.6387 - categorical_accuracy: 0.5431 - val_loss: 1.9278 - val_categorical_accuracy: 0.4533
# Epoch 21/50
# 164/164 [==============================] - 74s 450ms/step - loss: 1.6483 - categorical_accuracy: 0.5376 - val_loss: 1.9064 - val_categorical_accuracy: 0.4541
# Epoch 22/50
# 164/164 [==============================] - 73s 447ms/step - loss: 1.6125 - categorical_accuracy: 0.5491 - val_loss: 1.9325 - val_categorical_accuracy: 0.4378
# Epoch 23/50
# 164/164 [==============================] - 74s 448ms/step - loss: 1.5766 - categorical_accuracy: 0.5699 - val_loss: 1.8980 - val_categorical_accuracy: 0.4510
# Epoch 24/50
# 164/164 [==============================] - 74s 448ms/step - loss: 1.5788 - categorical_accuracy: 0.5586 - val_loss: 1.9214 - val_categorical_accuracy: 0.4486
# Epoch 25/50
# 164/164 [==============================] - 74s 450ms/step - loss: 1.5715 - categorical_accuracy: 0.5603 - val_loss: 1.8992 - val_categorical_accuracy: 0.4517
# Epoch 26/50
# 164/164 [==============================] - 73s 447ms/step - loss: 1.5410 - categorical_accuracy: 0.5674 - val_loss: 1.8879 - val_categorical_accuracy: 0.4571
# Epoch 27/50
# 164/164 [==============================] - 74s 448ms/step - loss: 1.5096 - categorical_accuracy: 0.5752 - val_loss: 1.8871 - val_categorical_accuracy: 0.4618
# Epoch 28/50
# 164/164 [==============================] - 74s 448ms/step - loss: 1.5236 - categorical_accuracy: 0.5701 - val_loss: 1.9085 - val_categorical_accuracy: 0.4525
# Epoch 29/50
# 164/164 [==============================] - 74s 450ms/step - loss: 1.4896 - categorical_accuracy: 0.5871 - val_loss: 1.8906 - val_categorical_accuracy: 0.4571
# Epoch 30/50
# 164/164 [==============================] - 74s 448ms/step - loss: 1.5055 - categorical_accuracy: 0.5838 - val_loss: 1.8533 - val_categorical_accuracy: 0.4687
# Epoch 31/50
# 164/164 [==============================] - 74s 449ms/step - loss: 1.4797 - categorical_accuracy: 0.5819 - val_loss: 1.8554 - val_categorical_accuracy: 0.4656
# Epoch 32/50
# 164/164 [==============================] - 74s 452ms/step - loss: 1.4626 - categorical_accuracy: 0.5895 - val_loss: 1.8249 - val_categorical_accuracy: 0.4656
# Epoch 33/50
# 164/164 [==============================] - 74s 451ms/step - loss: 1.4474 - categorical_accuracy: 0.5937 - val_loss: 1.8073 - val_categorical_accuracy: 0.4903
# Epoch 34/50
# 164/164 [==============================] - 74s 451ms/step - loss: 1.4556 - categorical_accuracy: 0.5956 - val_loss: 1.8315 - val_categorical_accuracy: 0.4811
# Epoch 35/50
# 164/164 [==============================] - 74s 451ms/step - loss: 1.4408 - categorical_accuracy: 0.5974 - val_loss: 1.8784 - val_categorical_accuracy: 0.4641
# Epoch 36/50
# 164/164 [==============================] - 74s 451ms/step - loss: 1.4271 - categorical_accuracy: 0.5911 - val_loss: 1.8065 - val_categorical_accuracy: 0.4757
# Epoch 37/50
# 164/164 [==============================] - 74s 450ms/step - loss: 1.4127 - categorical_accuracy: 0.6048 - val_loss: 1.8360 - val_categorical_accuracy: 0.4911
# Epoch 38/50
# 164/164 [==============================] - 74s 451ms/step - loss: 1.4049 - categorical_accuracy: 0.6092 - val_loss: 1.8130 - val_categorical_accuracy: 0.4857
# Epoch 39/50
# 164/164 [==============================] - 74s 451ms/step - loss: 1.4126 - categorical_accuracy: 0.6016 - val_loss: 1.8141 - val_categorical_accuracy: 0.4803
# Epoch 40/50
# 164/164 [==============================] - 74s 450ms/step - loss: 1.3905 - categorical_accuracy: 0.6058 - val_loss: 1.7775 - val_categorical_accuracy: 0.4934
# Epoch 41/50
# 164/164 [==============================] - 74s 449ms/step - loss: 1.3759 - categorical_accuracy: 0.6157 - val_loss: 1.8173 - val_categorical_accuracy: 0.4718
# Epoch 42/50
#  34/164 [=====>........................] - ETA: 47s - loss: 1.3858 - categorical_accuracy: 0.6167
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-bfed35ac384a> in <module>()
#       1 # Now let's practice our model
#       2
# ----> 3 model.fit(img_generator_flow_train, validation_data=img_generator_flow_valid, epochs=50)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3039     return graph_function._call_flat(
# -> 3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#    3042   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1962       # No tape is watching; skip to running the function.
#    1963       return self._build_call_outputs(self._inference_function.call(
# -> 1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#    1966         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     594               inputs=args,
#     595               attrs=attrs,
# --> 596               ctx=ctx)
#     597         else:
#     598           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_224 (Functi (None, 7, 7, 1280)        2257984
# _________________________________________________________________
# global_max_pooling2d_2 (Glob (None, 1280)              0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 25)                32025
# =================================================================
# Total params: 2,290,009
# Trainable params: 32,025
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %% [markdown]
# ## Accuracy

# %%
# We can visualize the learning process thanks to our history attribute from our model object

plt.plot(model.history.history["categorical_accuracy"], c="r", label="train_accuracy")
plt.plot(model.history.history["val_categorical_accuracy"], c="b", label="test_accuracy")
plt.legend(loc="upper left")
plt.show()

# %%
# Visualise train / Valid Loss
plt.plot(model.history.history["loss"], c="r", label="train_loss")
plt.plot(model.history.history["val_loss"], c="b", label="test_loss")
plt.legend(loc="upper left")
plt.show()

# %%
# Now we'll see if our machine can recognize some cars pictures. We're gonna take 5 pictures of cars (3 of our selction and 2 different)

data_predict = pathlib.Path("/content/drive/MyDrive/Jedha/Final_project/cars_pic/model_predict")
print(data_predict)

# %%
for pic_pred in data_predict.iterdir():
  print(pic_pred)

# %%
img_generator = tf.keras.preprocessing.image.ImageDataGenerator(#rotation_range=90,
                                                                brightness_range=(0.5,1), 
                                                                #shear_range=0.2, 
                                                                #zoom_range=0.2,
                                                                channel_shift_range=0.2,
                                                                horizontal_flip=True,
                                                                vertical_flip=True,
                                                                rescale=1./255)

# %%
img_generator_pred_valid = img_generator.flow_from_directory(
    directory="/content/drive/MyDrive/Jedha/Final_project/cars_pic/model_predict",
    target_size=(224, 224),
    batch_size=4,
    shuffle=True)

# %%
import os

rootdir = '/content/drive/MyDrive/Jedha/Final_project/cars_pic/cars_model' #définis le dossier où se situent les sous dossiers qui contiennent tes images
id_to_class = {} #définis un dictionnaire vide qui va servir à faire correspondre chaque entier (id) à une classe
i = 0 #initialise un itérateur

listdir_ = os.listdir(rootdir)
listdir_.sort()

for dir in listdir_: #parcours les sous-dossiers
    id_to_class[i] = dir #associe un entier comme clef à un nom de dossier (une classe) comme valeur
    i += 1 #incrémente ton itérateur

print(id_to_class) #vérifie ton dictionnaire

print(id_to_class[0]) #vérifie avec un test

# %%
from pathlib import Path

imgs, labels = next(iter(img_generator_pred_valid))
prediction = model.predict(imgs)
pred_labels = tf.argmax(prediction, axis = -1)
i = 0
for img, label in zip(imgs, labels):
  true_file_path = np.argmax(img_generator_pred_valid.labels == tf.argmax(label))
  true_label_name = Path(img_generator_pred_valid.filepaths[true_file_path]).parent.name
  print('Pred :', id_to_class[pred_labels[i].numpy()])
  print("Label :", true_label_name)
  plt.imshow(img)
  plt.show()
  i+=1
