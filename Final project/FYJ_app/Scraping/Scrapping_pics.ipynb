# %%
#Code pour supprimer un dossier et tout son contenu : attention à donner la bonne adresse !
#!rm -r "/content/drive/MyDrive/Jedha/Final_project/cars_pic/cars_model"

# %%
# !pip install -q jmd_imagescraper

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path
root = "/content/drive/MyDrive/Jedha/Final_project/cars_pic/cars_model"

from jmd_imagescraper.core import * # dont't worry, it's designed to work with import *

#duckduckgo_search(root, "Berlingo", "citroen berlingo extérieur 360°", max_results=350, img_layout =  ImgLayout.All)
#duckduckgo_search(root, "C4", "citroen C4 extérieur 360°", max_results=350, img_layout =  ImgLayout.All)
#duckduckgo_search(root, "C4 Cactus", "citroen c4 cactus 2015 extérieur 360°", max_results=350, img_layout =  ImgLayout.All)
#duckduckgo_search(root, "C3", "citroen C3 extérieur 360°", max_results=350, img_layout =  ImgLayout.All)
#duckduckgo_search(root, "C5 Aircross", "citroen C5 Aircross extérieur 360°", max_results=350, img_layout =  ImgLayout.All)
#duckduckgo_search(root, "108", "Peugeot 108 extérieur 360°", max_results=350, img_layout =  ImgLayout.All)
#duckduckgo_search(root, "208", "Peugeot 208 2014 extérieur 360°", max_results=350, img_layout =  ImgLayout.All)
#duckduckgo_search(root, "308", "Peugeot 308 1.2 2019 extérieur 360°", max_results=350, img_layout =  ImgLayout.All)
#duckduckgo_search(root, "3008", "Peugeot 3008 SUV 2019 extérieur 360°", max_results=350, img_layout =  ImgLayout.All)
#duckduckgo_search(root, "2008", "Peugeot 2008 2021", max_results=350, img_layout =  ImgLayout.All)
#duckduckgo_search(root, "Captur", "Renault Captur extérieur 360°", max_results=350, img_layout =  ImgLayout.All)
#duckduckgo_search(root, "Clio", "Renault clio 5 2021 extérieur 360°", max_results=350, img_layout =  ImgLayout.All)
#duckduckgo_search(root, "Megane", "Renault megane 4 2019 extérieur 360°", max_results=350, img_layout =  ImgLayout.All)
#duckduckgo_search(root, "Twingo", "Renault twingo 3 extérieur 360°", max_results=350, img_layout =  ImgLayout.All)
#duckduckgo_search(root, "Zoe", "Renault zoe extérieur 360°", max_results=350, img_layout =  ImgLayout.All)
#duckduckgo_search(root, "Aygo", "Toyota aygo vvt-i extérieur 360°", max_results=350, img_layout =  ImgLayout.All)
#duckduckgo_search(root, "C_HR", "Toyota c-hr extérieur 360°", max_results=350, img_layout =  ImgLayout.All)
#duckduckgo_search(root, "Corolla", "Toyota corolla hatchback extérieur 360°", max_results=350, img_layout =  ImgLayout.All)
#duckduckgo_search(root, "Rav 4", "Toyota rav4 2020 extérieur 360°", max_results=350, img_layout =  ImgLayout.All)
#duckduckgo_search(root, "Yaris", "Toyota yaris vvt-i 2020 extérieur 360°", max_results=350, img_layout =  ImgLayout.All)
#duckduckgo_search(root, "Golf", "Volkswagen golf 7 tsi extérieur 360°", max_results=350, img_layout =  ImgLayout.All)
#duckduckgo_search(root, "Polo", "Volkswagen Polo extérieur 360°", max_results=350, img_layout =  ImgLayout.All)
#duckduckgo_search(root, "T-Roc", "Volkswagen T-Roc TSI 2020 extérieur 360°", max_results=350, img_layout =  ImgLayout.All)
#duckduckgo_search(root, "Tiguan", "Volkswagen Tiguan extérieur 360°", max_results=350, img_layout =  ImgLayout.All)
#duckduckgo_search(root, "Up !", "Volkswagen up", max_results=350, img_layout =  ImgLayout.All)
# Out:
# Duckduckgo search: citroen berlingo extérieur 360°
# ...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='350' class='' max='350' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [350/350 01:17<00:00 Images downloaded]
#     </div>
# Duckduckgo search: citroen C4 extérieur 360°
# ...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
# ...

# %%
from pathlib import Path
root = "/content/drive/MyDrive/Jedha/Final_project/cars_pic/cars_model"

from jmd_imagescraper.core import * # dont't worry, it's designed to work with import *

duckduckgo_search(root, "2008", "Peugeot 2008 2021", max_results=350, img_layout =  ImgLayout.All)
duckduckgo_search(root, "Up !", "Volkswagen up", max_results=350, img_layout =  ImgLayout.All)
# Out:
# Duckduckgo search: Peugeot 2008 2021
# ...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='350' class='' max='350' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [350/350 00:32<00:00 Images downloaded]
#     </div>
# Duckduckgo search: Volkswagen up
# ...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
# ...

# %%
from pathlib import Path
root = "/content/drive/MyDrive/Jedha/Final_project/cars_pic/cars_model"

from jmd_imagescraper.imagecleaner import *

display_image_cleaner(root)
# Out:
# ...
# HTML(value='<h2>No images left to display in this folder.</h2>', layout=Layout(visibility='hidden'))
# GridBox(children=(VBox(children=(Image(value=b'', layout="Layout(width='150px')"), Button(description='Delete'…
